# %% [markdown]
# # Importing all the required libraries

# %%
# Import reqired libraries
import numpy as np
import yfinance as yf
import pandas as pd
import os
import matplotlib.pyplot as plt

# Set display options
pd.set_option('display.max_columns', None)  # Display all columns
pd.set_option('display.width', 1000)        # Set display width to a high value

# %% [markdown]
# # Defining miscellaneous function

# %%
# Function to print colored text
def print_colored(text, color):
    color_codes = {
        'black': '0;30',
        'red': '0;31',
        'green': '0;32',
        'yellow': '0;33',
        'blue': '0;34',
        'purple': '0;35',
        'cyan': '0;36',
        'white': '0;37',
        'bold_black': '1;30',
        'bold_red': '1;31',
        'bold_green': '1;32',
        'bold_yellow': '1;33',
        'bold_blue': '1;34',
        'bold_purple': '1;35',
        'bold_cyan': '1;36',
        'bold_white': '1;37'
    }
    color_code = color_codes.get(color, '0;30')  # Default to white if color not found
    print(f"\033[{color_code}m{text}\033[0m")

# %% [markdown]
# # Loading the datasets in pandas dataframes

# %%
# List of assets
assets = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'SPY', 'GLD', 'BTC-USD']

# Loop through each asset to load and display data
for asset in assets:
    # Define the file path
    file_path = f'../data/{asset}_enhanced_data.csv'
    
    # Load the data into a DataFrame
    df = pd.read_csv(file_path, index_col='Date', parse_dates=True)

# %% [markdown]
# # Display the first few rows of the DataFrame

# %%
for asset in assets:
    print_colored(f"\n{asset} data:", 'blue')
    print(df.head())
# Out:
# AAPL data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968
#
# MSFT data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968
#
# GOOGL data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968
#
# AMZN data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968
#
# TSLA data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968
#
# SPY data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968
#
# GLD data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968
#
# BTC-USD data:
#                   Open        High         Low       Close   Adj Close    Volume  Daily Return        MA20        MA50  Volatility
# Date
# 2014-11-05  330.683014  343.368988  330.683014  339.485992  339.485992  19817200      0.027214  355.747899  372.766840    0.026468
# 2014-11-06  339.458008  352.966003  338.424011  349.290009  349.290009  18797000      0.028879  354.024500  370.605960    0.027520
# 2014-11-07  349.817993  352.731995  341.776001  342.415009  342.415009  16834200     -0.019683  351.573151  368.965460    0.027100
# 2014-11-08  342.153992  347.032013  342.153992  345.488007  345.488007   8535470      0.008974  349.370251  367.979301    0.027315
# 2014-11-09  345.376007  363.626007  344.255005  363.264008  363.264008  24205600      0.051452  348.391202  367.066501    0.029968

# %% [markdown]
# # Basic Data Information

# %%
for asset in assets:
  print_colored(f"\n{asset} DataFrame Info:", "blue")
  print(df.info())
# Out:
# AAPL DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None
#
# MSFT DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None
#
# GOOGL DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None
#
# AMZN DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None
#
# TSLA DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None
#
# SPY DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None
#
# GLD DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None
#
# BTC-USD DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2979 entries, 2014-11-05 to 2022-12-31
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          2979 non-null   float64
#  1   High          2979 non-null   float64
#  2   Low           2979 non-null   float64
#  3   Close         2979 non-null   float64
#  4   Adj Close     2979 non-null   float64
#  5   Volume        2979 non-null   int64
#  6   Daily Return  2979 non-null   float64
#  7   MA20          2979 non-null   float64
#  8   MA50          2979 non-null   float64
#  9   Volatility    2979 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 256.0 KB
# None

# %% [markdown]
# # Statistical Information

# %%
# Loop through each asset to load data, explore, and visualize
for asset in assets:
  # Basic Data Exploration
  print_colored(f"\n{asset} Summary Statistics:", "blue")
  print(df.describe())
# Out:
# AAPL Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076
#
# MSFT Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076
#
# GOOGL Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076
#
# AMZN Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076
#
# TSLA Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076
#
# SPY Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076
#
# GLD Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076
#
# BTC-USD Summary Statistics:
#                Open          High           Low         Close     Adj Close        Volume  Daily Return          MA20          MA50   Volatility
# count   2979.000000   2979.000000   2979.000000   2979.000000   2979.000000  2.979000e+03   2979.000000   2979.000000   2979.000000  2979.000000
# mean   13063.683027  13393.078374  12694.951532  13067.598998  13067.598998  1.661221e+10      0.002058  13015.305939  12931.973654     0.034376
# std    16242.954680  16658.634539  15761.506018  16237.839799  16237.839799  2.002783e+10      0.038381  16184.443830  16095.328257     0.016896
# min      176.897003    211.731003    171.509995    178.102997    178.102997  6.491650e+06     -0.371695    226.383199    232.261620     0.004868
# 25%      740.573517    747.772003    732.605499    740.902985    740.902985  1.218035e+08     -0.013384    716.694554    671.015892     0.022587
# 50%     7253.241699   7399.041016   7086.124023   7257.665039   7257.665039  8.041160e+09      0.001803   7248.665674   7155.266318     0.031529
# 75%    17006.056641  17329.349609  16674.797852  17004.559570  17004.559570  2.822578e+10      0.017739  16957.979834  16813.907959     0.044060
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125  3.509679e+11      0.252472  63149.319727  60801.771016     0.109076

# %%
for asset in assets:
  print_colored(f"\n{asset} Missing Values:", "blue")
  print(df.isnull().sum())
# Out:
# AAPL Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64
#
# MSFT Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64
#
# GOOGL Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64
#
# AMZN Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64
#
# TSLA Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64
#
# SPY Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64
#
# GLD Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64
#
# BTC-USD Missing Values:
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# Daily Return    0
# MA20            0
# MA50            0
# Volatility      0
# dtype: int64

# %%
# Loop through each asset to load data, explore, and visualize
for asset in assets:
  
  # Visualize Adjusted Close Prices
  plt.figure(figsize=(14, 7))
  plt.plot(df['Adj Close'], label=f'{asset} Adj Close')
  plt.title(f'{asset} - Adjusted Close Prices')
  plt.xlabel('Date')
  plt.ylabel('Price')
  plt.legend()
  plt.show()
  
  # Visualize Daily Returns
  plt.figure(figsize=(14, 7))
  plt.plot(df['Daily Return'], label=f'{asset} Daily Return')
  plt.title(f'{asset} - Daily Returns')
  plt.xlabel('Date')
  plt.ylabel('Daily Return')
  plt.legend()
  plt.show()
  
  # Plot Moving Averages
  plt.figure(figsize=(14, 7))
  plt.plot(df['Adj Close'], label='Adj Close')
  plt.plot(df['MA20'], label='MA20')
  plt.plot(df['MA50'], label='MA50')
  plt.title(f'{asset} - Moving Averages')
  plt.xlabel('Date')
  plt.ylabel('Price')
  plt.legend()
  plt.show()
  
  # Plot Volatility
  plt.figure(figsize=(14, 7))
  plt.plot(df['Volatility'], label='Volatility')
  plt.title(f'{asset} - Volatility')
  plt.xlabel('Date')
  plt.ylabel('Volatility')
  plt.legend()
  plt.show()

# %%
# Correlation Analysis
# Create a DataFrame to store adjusted close prices of all assets
adj_close_df = pd.DataFrame()

for asset in assets:
    file_path = f'../data/{asset}_enhanced_data.csv'
    df = pd.read_csv(file_path, index_col='Date', parse_dates=True)
    adj_close_df[asset] = df['Adj Close']

# Compute correlation matrix
corr_matrix = adj_close_df.corr()

# Visualize the correlation matrix
plt.figure(figsize=(10, 8))
plt.matshow(corr_matrix, cmap='coolwarm', fignum=1)
plt.colorbar()
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.title('Correlation Matrix of Adjusted Close Prices', pad=20)
plt.show()
